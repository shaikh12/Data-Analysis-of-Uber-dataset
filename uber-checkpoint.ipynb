# %%
import pandas as pd

df=pd.read_csv('Uber-Jan-Feb-FOIL.csv')
df
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 0                    B02512  01-01-2015              190   1132
# 1                    B02765  01-01-2015              225   1765
# 2                    B02764  01-01-2015             3427  29421
# 3                    B02682  01-01-2015              945   7679
# 4                    B02617  01-01-2015             1228   9537
# 5                    B02598  01-01-2015              870   6903
# 6                    B02598  01-02-2015              785   4768
# 7                    B02617  01-02-2015             1137   7065
# 8                    B02512  01-02-2015              175    875
# 9                    B02682  01-02-2015              890   5506
# 10                   B02765  01-02-2015              196   1001
# 11                   B02764  01-02-2015             3147  19974
# 12                   B02765  01-03-2015              201   1526
# 13                   B02617  01-03-2015             1188  10664
# ...

# %%
# SHOWING THE MAXIMUM VEHICLES ONN A SINGLE DAY

df['active_vehicles'].max()
# Out:
# 4395

# %%
# SHOWING THE MINIMUM VEHICLES ONN A SINGLE DAY
 
df['active_vehicles'].min()
# Out:
# 112

# %%
# SHOWING THE MAXIMUM TRIPS OF CAB IN A SINGLE DAY

df['trips'].max()
# Out:
# 45858

# %%
# SHOWING THE MINIMUM TRIPS OF CAB IN A SINGLE DAY

df['trips'].min()
# Out:
# 629

# %%
# THIS SHOWS THE LAST DATE IN THE DATA

df['date'].max()
# Out:
# '2/28/2015'

# %%
# THIS SHOWS THE FIRST DATE OF DATASET

df['date'].min()
# Out:
# '01-01-2015'

# %%
# WE CAN ALSO DISPLAY SINGLE COLUMN OF DATASET.

df.date
# Out:
# 0      01-01-2015
# 1      01-01-2015
# 2      01-01-2015
# 3      01-01-2015
# 4      01-01-2015
# 5      01-01-2015
# 6      01-02-2015
# 7      01-02-2015
# 8      01-02-2015
# 9      01-02-2015
# 10     01-02-2015
# 11     01-02-2015
# 12     01-03-2015
# 13     01-03-2015
# 14     01-03-2015
# 15     01-03-2015
# 16     01-03-2015
# 17     01-03-2015
# 18     01-04-2015
# 19     01-04-2015
# 20     01-04-2015
# 21     01-04-2015
# 22     01-04-2015
# 23     01-04-2015
# 24     01-05-2015
# 25     01-05-2015
# 26     01-05-2015
# 27     01-05-2015
# 28     01-05-2015
# 29     01-05-2015
#           ...
# 324     2/24/2015
# 325     2/24/2015
# 326     2/24/2015
# 327     2/24/2015
# 328     2/24/2015
# 329     2/24/2015
# 330     2/25/2015
# 331     2/25/2015
# 332     2/25/2015
# 333     2/25/2015
# 334     2/25/2015
# 335     2/25/2015
# 336     2/26/2015
# 337     2/26/2015
# 338     2/26/2015
# 339     2/26/2015
# 340     2/26/2015
# 341     2/26/2015
# 342     2/27/2015
# ...

# %%
df.active_vehicles   # df['active_vehicles]    # SHOWINH SINGLE COLUMNS
# Out:
# 0       190
# 1       225
# 2      3427
# 3       945
# 4      1228
# 5       870
# 6       785
# 7      1137
# 8       175
# 9       890
# 10      196
# 11     3147
# 12      201
# 13     1188
# 14      818
# 15      915
# 16      173
# 17     3215
# 18      147
# 19      812
# 20      746
# 21      183
# 22     1088
# 23     2862
# 24      194
# 25      951
# 26     1218
# 27     3387
# 28      907
# 29      227
#        ...
# 324    3965
# 325     247
# 326    1061
# 327    1346
# 328    1456
# 329     698
# 330     246
# 331    1076
# 332     706
# 333    1395
# 334    1473
# 335    3934
# 336    1134
# 337    1539
# 338    1465
# 339     243
# 340     745
# 341    4101
# 342     786
# 343    1551
# 344    1114
# 345     272
# 346    4253
# 347    1510
# 348     994
# 349    3952
# 350    1372
# 351    1386
# 352     230
# 353     747
# Name: active_vehicles, Length: 354, dtype: int64

# %%
df.trips  # am not able to see the whole column.
# Out:
# 0       1132
# 1       1765
# 2      29421
# 3       7679
# 4       9537
# 5       6903
# 6       4768
# 7       7065
# 8        875
# 9       5506
# 10      1001
# 11     19974
# 12      1526
# 13     10664
# 14      7432
# 15      8010
# 16      1088
# 17     29729
# 18       791
# 19      5621
# 20      5223
# 21       993
# 22      7729
# 23     20441
# 24       984
# 25      6012
# 26      7899
# 27     20926
# 28      5798
# 29      1133
#        ...
# 324    34686
# 325     1869
# 326     9954
# 327    12497
# 328    13719
# 329     6390
# 330     1647
# 331     9405
# 332     6178
# 333    12693
# 334    12811
# 335    31957
# 336    10661
# 337    14461
# 338    13814
# 339     1797
# 340     6744
# 341    36091
# 342     7563
# 343    14677
# 344    10755
# 345     2056
# 346    38780
# 347    14975
# 348    10319
# 349    39812
# 350    14022
# 351    14472
# 352     1803
# 353     7753
# Name: trips, Length: 354, dtype: int64

# %%
rows, column=df.shape    # tHIS WILL GIVE THE DIMENSION OF THE DATSET

# %%
rows     # PRINTS THE TOTAL NUMBER OF ROWS
# Out:
# 354

# %%
column   # PRINTS THE TOTAL NUMBER OF COLUMNS
# Out:
# 4

# %%
df[:]     # [:] THIS WILL PRINT THE WHOLE DATASET  . JUST A ANOTHER WAY OF PRINTING
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 0                    B02512  01-01-2015              190   1132
# 1                    B02765  01-01-2015              225   1765
# 2                    B02764  01-01-2015             3427  29421
# 3                    B02682  01-01-2015              945   7679
# 4                    B02617  01-01-2015             1228   9537
# 5                    B02598  01-01-2015              870   6903
# 6                    B02598  01-02-2015              785   4768
# 7                    B02617  01-02-2015             1137   7065
# 8                    B02512  01-02-2015              175    875
# 9                    B02682  01-02-2015              890   5506
# 10                   B02765  01-02-2015              196   1001
# 11                   B02764  01-02-2015             3147  19974
# 12                   B02765  01-03-2015              201   1526
# 13                   B02617  01-03-2015             1188  10664
# ...

# %%
# IF WE WANT TO KNOW ABOUT THE NUMBER OF COLUMNS IN THE DATA

df.columns
# Out:
# Index(['dispatching_base_number', 'date', 'active_vehicles', 'trips'], dtype='object')

# %%
# TYPE DEFINES THE TYPE OF COLUMN

type(df.trips)
# Out:
# pandas.core.series.Series

# %%
type(df.active_vehicles)
# Out:
# pandas.core.series.Series

# %%
# IF YOU WANT TO DISPLAY TWO COLUMNS TOGETHER

df[['active_vehicles', 'trips']]
# Out:
#      active_vehicles  trips
# 0                190   1132
# 1                225   1765
# 2               3427  29421
# 3                945   7679
# 4               1228   9537
# 5                870   6903
# 6                785   4768
# 7               1137   7065
# 8                175    875
# 9                890   5506
# 10               196   1001
# 11              3147  19974
# 12               201   1526
# 13              1188  10664
# 14               818   7432
# 15               915   8010
# 16               173   1088
# 17              3215  29729
# 18               147    791
# 19               812   5621
# 20               746   5223
# 21               183    993
# 22              1088   7729
# 23              2862  20441
# 24               194    984
# 25               951   6012
# 26              1218   7899
# 27              3387  20926
# 28               907   5798
# 29               227   1133
# ..               ...    ...
# 324             3965  34686
# ...

# %%
# IF WANT TO DISPLAY 3 COLUMNS

df[['active_vehicles', 'trips', 'date']]
# Out:
#      active_vehicles  trips        date
# 0                190   1132  01-01-2015
# 1                225   1765  01-01-2015
# 2               3427  29421  01-01-2015
# 3                945   7679  01-01-2015
# 4               1228   9537  01-01-2015
# 5                870   6903  01-01-2015
# 6                785   4768  01-02-2015
# 7               1137   7065  01-02-2015
# 8                175    875  01-02-2015
# 9                890   5506  01-02-2015
# 10               196   1001  01-02-2015
# 11              3147  19974  01-02-2015
# 12               201   1526  01-03-2015
# 13              1188  10664  01-03-2015
# 14               818   7432  01-03-2015
# 15               915   8010  01-03-2015
# 16               173   1088  01-03-2015
# 17              3215  29729  01-03-2015
# 18               147    791  01-04-2015
# 19               812   5621  01-04-2015
# 20               746   5223  01-04-2015
# 21               183    993  01-04-2015
# ...

# %%
df.describe()  # perfom numerical operations on column which have numeric data
# Out:
#        active_vehicles         trips
# count       354.000000    354.000000
# mean       1307.435028  11667.316384
# std        1162.510626  10648.284865
# min         112.000000    629.000000
# 25%         296.750000   2408.500000
# 50%        1077.000000   9601.000000
# 75%        1417.000000  13711.250000
# max        4395.000000  45858.000000

# %%
# THIS WILL DISPLAY THE DETAILS OF THOSE TRIPS WHICH ARE GREATER THAN 10000 IN A SINGLE DAY

df[df.trips > 10000]
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 2                    B02764  01-01-2015             3427  29421
# 11                   B02764  01-02-2015             3147  19974
# 13                   B02617  01-03-2015             1188  10664
# 17                   B02764  01-03-2015             3215  29729
# 23                   B02764  01-04-2015             2862  20441
# 27                   B02764  01-05-2015             3387  20926
# 30                   B02764  01-06-2015             3473  25301
# 32                   B02617  01-06-2015             1336  10128
# 36                   B02617  01-07-2015             1363  11528
# 38                   B02764  01-07-2015             3603  29949
# 43                   B02598  01-08-2015             1070  10050
# 45                   B02682  01-08-2015             1135  10416
# 46                   B02764  01-08-2015             3831  33802
# 47                   B02617  01-08-2015             1463  13462
# ...

# %%
df[df.trips > 30000]   # SAME AS ABOVE
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 46                   B02764  01-08-2015             3831  33802
# 50                   B02764  01-09-2015             3820  33517
# 58                   B02764  01-10-2015             3558  38864
# 88                   B02764   1/15/2015             3840  31214
# 92                   B02764   1/16/2015             3975  34822
# 101                  B02764   1/17/2015             3657  36318
# 105                  B02764   1/18/2015             3290  35182
# 127                  B02764   1/22/2015             3889  30091
# 135                  B02764   1/23/2015             4040  33756
# 139                  B02764   1/24/2015             3652  39187
# 169                  B02764   1/29/2015             3959  31637
# 177                  B02764   1/30/2015             4124  39110
# 184                  B02764   1/31/2015             3947  44297
# 191                  B02764  02-01-2015             3740  37468
# ...

# %%
# IF YOU WANT TO KNOW  THE NO. OF ACTIVE VEHICLES GREATER THAN 1000 IN A SINGLE DAY

df[df.active_vehicles > 1000]
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 2                    B02764  01-01-2015             3427  29421
# 4                    B02617  01-01-2015             1228   9537
# 7                    B02617  01-02-2015             1137   7065
# 11                   B02764  01-02-2015             3147  19974
# 13                   B02617  01-03-2015             1188  10664
# 17                   B02764  01-03-2015             3215  29729
# 22                   B02617  01-04-2015             1088   7729
# 23                   B02764  01-04-2015             2862  20441
# 26                   B02617  01-05-2015             1218   7899
# 27                   B02764  01-05-2015             3387  20926
# 30                   B02764  01-06-2015             3473  25301
# 31                   B02682  01-06-2015             1022   7491
# 32                   B02617  01-06-2015             1336  10128
# 36                   B02617  01-07-2015             1363  11528
# ...

# %%
df[df.active_vehicles > 2000 ]    # SAME AS ABOVE
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 2                    B02764  01-01-2015             3427  29421
# 11                   B02764  01-02-2015             3147  19974
# 17                   B02764  01-03-2015             3215  29729
# 23                   B02764  01-04-2015             2862  20441
# 27                   B02764  01-05-2015             3387  20926
# 30                   B02764  01-06-2015             3473  25301
# 38                   B02764  01-07-2015             3603  29949
# 46                   B02764  01-08-2015             3831  33802
# 50                   B02764  01-09-2015             3820  33517
# 58                   B02764  01-10-2015             3558  38864
# 63                   B02764  01-11-2015             3186  27681
# 66                   B02764  01-12-2015             3499  26852
# 76                   B02764   1/13/2015             3658  29983
# 78                   B02764   1/14/2015             3736  29550
# ...

# %%
# am not able to see the count at the end 

df[df.active_vehicles > 3000 ]
# Out:
#     dispatching_base_number        date  active_vehicles  trips
# 2                    B02764  01-01-2015             3427  29421
# 11                   B02764  01-02-2015             3147  19974
# 17                   B02764  01-03-2015             3215  29729
# 27                   B02764  01-05-2015             3387  20926
# 30                   B02764  01-06-2015             3473  25301
# 38                   B02764  01-07-2015             3603  29949
# 46                   B02764  01-08-2015             3831  33802
# 50                   B02764  01-09-2015             3820  33517
# 58                   B02764  01-10-2015             3558  38864
# 63                   B02764  01-11-2015             3186  27681
# 66                   B02764  01-12-2015             3499  26852
# 76                   B02764   1/13/2015             3658  29983
# 78                   B02764   1/14/2015             3736  29550
# 88                   B02764   1/15/2015             3840  31214
# ...

# %%
# IF YOU WANT TO PRINT THE WHOLE DETAIS OF  TRIPS WHEN IT IS MAXIMUM, i.e. THE WHOLE ROW

df[df.trips==df['trips'].max()]
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 264                  B02764  2/14/2015             4129  45858

# %%
# IF YOU WANT TO PRINT THE WHOLE DETAIS OF  TRIPS WHEN IT IS MINIMUM, i.e. THE WHOLE ROW


df[df.trips==df['trips'].min()]
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 160                  B02512  1/27/2015              112    629

# %%
# IF YOU WANT TO PRINT THE WHOLE DETAIS OF  active vehicles WHEN IT IS MAXIMUM, i.e. THE WHOLE ROW


df[df.active_vehicles==df['active_vehicles'].max()]
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 260                  B02764  2/13/2015             4395  43561

# %%
# IF YOU WANT TO PRINT THE WHOLE DETAIS OF  active vehicles WHEN IT IS minimum, i.e. THE WHOLE ROW


df[df.active_vehicles==df['active_vehicles'].min()]
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 160                  B02512  1/27/2015              112    629

# %%
# suppose you want to display other 2 columns when active vehicles has  the maximum number

df[['dispatching_base_number', 'active_vehicles']][df.active_vehicles==df['active_vehicles'].max()]
# Out:
#     dispatching_base_number  active_vehicles
# 260                  B02764             4395

# %%
# same as above

df[['dispatching_base_number', 'trips']][df.active_vehicles==df['active_vehicles'].max()]
# Out:
#     dispatching_base_number  trips
# 260                  B02764  43561

# %%
# index method will give the starting and ending point of the data

df.index
# Out:
# RangeIndex(start=0, stop=354, step=1)

# %%
# info -> this is just another method to print the whole dataset

df.info
# Out:
# <bound method DataFrame.info of     dispatching_base_number        date  active_vehicles  trips
# 0                    B02512  01-01-2015              190   1132
# 1                    B02765  01-01-2015              225   1765
# 2                    B02764  01-01-2015             3427  29421
# 3                    B02682  01-01-2015              945   7679
# 4                    B02617  01-01-2015             1228   9537
# 5                    B02598  01-01-2015              870   6903
# 6                    B02598  01-02-2015              785   4768
# 7                    B02617  01-02-2015             1137   7065
# 8                    B02512  01-02-2015              175    875
# 9                    B02682  01-02-2015              890   5506
# 10                   B02765  01-02-2015              196   1001
# 11                   B02764  01-02-2015             3147  19974
# 12                   B02765  01-03-2015              201   1526
# ...

# %%
# iloc[] method displays certain elements of data , depending upon which element we give inside the square brackets.
#  [:] this signifies that all

df.iloc[0,:]
# Out:
# dispatching_base_number        B02512
# date                       01-01-2015
# active_vehicles                   190
# trips                            1132
# Name: 0, dtype: object

# %%
#df.sort_values(trips)

# %%
# CHANGING THE INDEX WITH ANY ANOTHER COLUMN

df.set_index('date', inplace=True)

# %%
df  # INDEX CHANGED
# Out:
#            dispatching_base_number  active_vehicles  trips
# date
# 01-01-2015                  B02512              190   1132
# 01-01-2015                  B02765              225   1765
# 01-01-2015                  B02764             3427  29421
# 01-01-2015                  B02682              945   7679
# 01-01-2015                  B02617             1228   9537
# 01-01-2015                  B02598              870   6903
# 01-02-2015                  B02598              785   4768
# 01-02-2015                  B02617             1137   7065
# 01-02-2015                  B02512              175    875
# 01-02-2015                  B02682              890   5506
# 01-02-2015                  B02765              196   1001
# 01-02-2015                  B02764             3147  19974
# 01-03-2015                  B02765              201   1526
# 01-03-2015                  B02617             1188  10664
# 01-03-2015                  B02598              818   7432
# ...

# %%
# TO RESET THE INDEX

df.reset_index(inplace=True)

# %%
df  #INDEX CHANGED
# Out:
#            date dispatching_base_number  active_vehicles  trips
# 0    01-01-2015                  B02512              190   1132
# 1    01-01-2015                  B02765              225   1765
# 2    01-01-2015                  B02764             3427  29421
# 3    01-01-2015                  B02682              945   7679
# 4    01-01-2015                  B02617             1228   9537
# 5    01-01-2015                  B02598              870   6903
# 6    01-02-2015                  B02598              785   4768
# 7    01-02-2015                  B02617             1137   7065
# 8    01-02-2015                  B02512              175    875
# 9    01-02-2015                  B02682              890   5506
# 10   01-02-2015                  B02765              196   1001
# 11   01-02-2015                  B02764             3147  19974
# 12   01-03-2015                  B02765              201   1526
# 13   01-03-2015                  B02617             1188  10664
# ...

# %%
# IMPORTING NUMPY(NUMERICAL PYTHON) MODULE , USED TO DECLARE ARRAY AND  FOR SCIENTIFIC COMPUTATIONS


import numpy as np    

df1=np.array(['trips'])
print(df1.itemsize)   # itemsize is 20 ???????
# Out:
# 20

# %%
df1=np.array(['active_vehicles'])
print(df1.itemsize)              # THIS WILL PRINT THE ITEMSIZE OF ACTIVE VEHICLES
# Out:
# 60

# %%
# numpy.flags
# The ndarray object has the following attributes. Its current values are returned by this function.


# C_CONTIGUOUS (C)
# The data is in a single, C-style contiguous segment

# F_CONTIGUOUS (F)
# The data is in a single, Fortran-style contiguous segment


# OWNDATA (O)
# The array owns the memory it uses or borrows it from another object


# WRITEABLE (W)
# The data area can be written to. Setting this to False locks the data, making it read-only


# ALIGNED (A)
# The data and all elements are aligned appropriately for the hardware


# UPDATEIFCOPY (U)
# This array is a copy of some other array. When this array is deallocated, the base array will be updated with the contents of this array

# %%
df1=np.array(['trips'])
df1.flags
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False
#   UPDATEIFCOPY : False

# %%
df1=np.array([['trips'],['active_vehicles'],['date']])

# %%
# TO KNOW THE DIMENSION OF THE ARRAY MADE BY NUMPY MODULE
# ndim fucntion is used
 
df1.ndim
# Out:
# 2

# %%
df1.itemsize  # itemsize wil give the item size of data's element
# Out:
# 60

# %%
df1.dtype
# Out:
# dtype('<U15')

# %%
df1.size    # size will give the total size
# Out:
# 3

# %%
df1.shape  # shape-> dimension
# Out:
# (3, 1)

# %%
# SLICING THE DATA   .....for that head() method is  used

df.head()   # By default it print frist 5 rows
# Out:
#          date dispatching_base_number  active_vehicles  trips
# 0  01-01-2015                  B02512              190   1132
# 1  01-01-2015                  B02765              225   1765
# 2  01-01-2015                  B02764             3427  29421
# 3  01-01-2015                  B02682              945   7679
# 4  01-01-2015                  B02617             1228   9537

# %%
df.head(7)   # you can give as many you want
# Out:
#          date dispatching_base_number  active_vehicles  trips
# 0  01-01-2015                  B02512              190   1132
# 1  01-01-2015                  B02765              225   1765
# 2  01-01-2015                  B02764             3427  29421
# 3  01-01-2015                  B02682              945   7679
# 4  01-01-2015                  B02617             1228   9537
# 5  01-01-2015                  B02598              870   6903
# 6  01-02-2015                  B02598              785   4768

# %%
# if you want to print the last elements of your data ....tail() method is used

df.tail()  #by default it prints last 5 rows only
# Out:
#           date dispatching_base_number  active_vehicles  trips
# 349  2/28/2015                  B02764             3952  39812
# 350  2/28/2015                  B02617             1372  14022
# 351  2/28/2015                  B02682             1386  14472
# 352  2/28/2015                  B02512              230   1803
# 353  2/28/2015                  B02765              747   7753

# %%
df.tail(2)
# Out:
#           date dispatching_base_number  active_vehicles  trips
# 352  2/28/2015                  B02512              230   1803
# 353  2/28/2015                  B02765              747   7753

# %%
import matplotlib.pyplot as plt
% matplotlib inline

# %%
plt.xlabel('<<<< Trips  >>>>>')
plt.ylabel('Date')
plt.title('Uber representation')
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-b4e66c5f4476> in <module>()
#       2 plt.ylabel('Date')
#       3 plt.title('Uber representation')
# ----> 4 plt.plot(x,y)
#
# NameError: name 'x' is not defined

# %%
x=df[df.trips > 40000]

# %%
x
x.date

# %%
plt.title('Uber data showing Maximum Trips')
plt.xlabel('X-axis')
plt.ylabel('Y-label')
plt.grid()
plt.plot(x, label='Trips')
plt.show()

# %%
x

# %%
x.trips

# %%
plt.title('Representing maximum Trips of uber ')
plt.xlabel('----DATE----')
plt.ylabel('----TRIPS----')

plt.bar(x.date, x.trips, color='r')

# %%
plt.title('Representing Number of Active Vehicles when trips > 40K')
plt.ylabel('NO. of Active Vehicles')
plt.xlabel('DATE')

plt.bar(x.date, x.active_vehicles, color='g')

# %%
y=df[df.active_vehicles > 4000]

# %%
y

# %%
y.active_vehicles

# %%
y.trips

# %%
y.date, y.trips   #PRINTING TWO COLUMNS

# %%
plt.title('showing vehicles when greater than 4K on a single day')
plt.xlabel(' DATE ')
plt.ylabel('NO. OF ACTIVE VEHICLES')

plt.bar(y.date,  y.active_vehicles, color='yellow')

# %%
# now showing NUMBER OF TRIPS on those days when ACTIVE VEHICLES > 4000

# %%
plt.title('uber Trips')
plt.xlabel('Date on which vehicles are > 4k on ROAD')
plt.ylabel('number of trips')
plt.bar(y.date, y.trips, color='violet')

# %%
plt.savefig("uber_trips.jpeg", bbox_inches='tight', pad_inches=2)

# %%
 # TOTAL NUMBER OF TRIPS

# %%
sum_total=0

for i in range(len(df.trips)):
    sum_total +=df.trips[i]

# %%
print(sum_total)
# Out:
# 4130230

# %%
# Total number of ACTIVE VEHICLES

# %%
total=0
for i in range(len(df.active_vehicles)):
    total +=df.active_vehicles[i]

# %%
print(total)
# Out:
# 462832

# %%
# REPORTS

# %%
# 1. on a single day, when there is minimum vehicles on the road.. Then that day had the Minimum Trips.

# %%
# 2. But when there is Maximum cars on road then that days was not the maximum trips RATHER when cars was just lesser than the maximum then the day had the maximum trips
